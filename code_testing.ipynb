# %%
from feature_creation import *

# %%
X, y = create_features()

# %%
print("Number of features: ", X.shape[1] - 1)
# Out:
# Number of features:  121

# %%
X
# Out:
#       prism_consumer_id  CASH MANAGEMENT_cnt  CD_cnt  CHECKING_cnt
# 0                     0                    0       0             1  \
# 1                     2                    0       0             1
# 2                     4                    0       0             1
# 3                     7                    0       0             2
# 4                     9                    0       0             1
# ...                 ...                  ...     ...           ...
# 2973               5941                    0       0             1
# 2974               5943                    0       0             1
# 2975               5944                    0       0             1
# 2976               5945                    0       0             1
# 2977               5949                    0       0             1
#
#       CREDIT CARD_cnt  MONEY MARKET_cnt  PREPAID_cnt  SAVINGS_cnt
# 0                   0                 0            0            1  \
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2973    0
# 2974    0
# 2975    0
# 2976    0
# 2977    0
# Name: FPF_TARGET, Length: 2978, dtype: int64
